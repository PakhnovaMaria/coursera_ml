# %% [markdown]
# Для запуска демонстрации необходимо выполнить следующие шаги:
#
# 1. Запустить *model.ipynb*
# 2. Обучить классификатор
#     1. Скачать данные по отзывам по указанным ссылкам
#     2. Объекты должны сохраниться в папке **model** на уровень выше
# 3. Создать виртуальную среду
# 4. Запустить приложение
# 5. Демонстрация будет доступна по адресу http://127.0.0.1:5000/sentiment-film
#
# Итоговая директория проета должна выглядеть следующим образом:
#
# - demo
# - - data
# - - - kinopoisk_bottom100
# - - - kinopoisk_top250
# - - flaskr
# - - - __init__.py
# - - - model.ipynb
# - - - sentiment_classifier.py
# - - - templates.py
# - - - README.ipynb
# - - - demo1.png
# - - - demo2.png
# - - - demo3.png
# - - model
# - - - LogisticRegression.joblib
# - - - TfidfVectorizer.joblib
# - - venv

# %%
from IPython.display import Image
Image(filename='demo1.png')

# %%
Image(filename='demo2.png')

# %%
Image(filename='demo3.png')
